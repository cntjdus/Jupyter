# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # create data points

# %%
df = pd.DataFrame(columns=['x', 'y'])

# %%
df.loc[0] = [3,1]
df.loc[1] = [4,1]
df.loc[2] = [3,2]
df.loc[3] = [4,2]
df.loc[4] = [10,5]
df.loc[5] = [10,6]
df.loc[6] = [11,5]
df.loc[7] = [11,6]
df.loc[8] = [15,1]
df.loc[9] = [15,2]
df.loc[10] = [16,1]
df.loc[11] = [16,2]

# %%
df.head(20)
# Out:
#      x  y
# 0    3  1
# 1    4  1
# 2    3  2
# 3    4  2
# 4   10  5
# 5   10  6
# 6   11  5
# 7   11  6
# 8   15  1
# 9   15  2
# 10  16  1
# 11  16  2

# %% [markdown]
# # Visualize data points on 2D plot

# %%
# visualize data point
sns.lmplot(x='x', y='y', data=df, fit_reg=False, scatter_kws={"s": 200}) # x-axis, y-axis, data, no line, marker size

# title
plt.title('kmean plot')

# x-axis label
plt.xlabel('x')

# y-axis label
plt.ylabel('y')
# Out:
# Text(42.25000000000001, 0.5, 'y')

# %% [markdown]
# # k-mean clustering

# %%
# convert dataframe to numpy array
data_points = df.values

# %%
kmeans = KMeans(n_clusters=3).fit(data_points)
# Out:
# C:\Users\smons\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# cluster id for each data point
kmeans.labels_
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 0, 2, 2, 2, 2], dtype=int32)

# %%
# this is final centroids position
kmeans.cluster_centers_
# Out:
# array([[10.5,  5.5],
#        [ 3.5,  1.5],
#        [15.5,  1.5]])

# %%
df['cluster_id'] = kmeans.labels_

# %%
df.head(12)
# Out:
#      x  y  cluster_id
# 0    3  1           1
# 1    4  1           1
# 2    3  2           1
# 3    4  2           1
# 4   10  5           0
# 5   10  6           0
# 6   11  5           0
# 7   11  6           0
# 8   15  1           2
# 9   15  2           2
# 10  16  1           2
# 11  16  2           2

# %%
sns.lmplot(x= 'x', y= 'y', data=df, fit_reg=False,  # x-axis, y-axis, data, no line
           scatter_kws={"s": 150}, # marker size
           hue="cluster_id") # color

# title
plt.title('after kmean clustering')
# Out:
# Text(0.5, 1.0, 'after kmean clustering')
